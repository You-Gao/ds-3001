# %% [markdown]
# ## EDA LAB
#
# The General Social Survey (GSS) is a bi-annual nationally representative survey of Americans, with almost 7000 different questions asked since the survey began in the 1970s. It has straightforward questions about respondents' demographic information, but also questions like "Does your job regularly require you to perform repetitive or forceful hand movements or involve awkward postures?" or "How often do the demands of your job interfere with your family life?" There are a variety of controversial questions. No matter what you're curious about, there's something interesting in here to check out. The codebook is 904 pages (use CTRL+F to search it).
#
# The data and codebook are available at:
# https://gss.norc.org/us/en/gss/get-the-data.html
#
# The datasets are so large that it might make sense to pick the variables you want, and then download just those variables from:
# https://gssdataexplorer.norc.org/variables/vfilter
#
# Here is your task:
# 1. Download a small (5-15) set of variables of interest.
# 2. Write a short description of the data you chose, and why. (1 page) [Variables and Why](#1.-Variables-and-Why)
# 3. Load the data using Pandas. Clean them up for EDA. Do this in a notebook with comments or markdown chunks explaining your choices.[Clean-up](#2.-Clean-up)
# 4. Produce some numeric summaries and visualizations. (1-3 pages)
# 5. Describe your findings in 1-2 pages.
# 6. If you have other content that you think absolutely must be included, you can include it in an appendix of any length.
#
# For example, you might want to look at how aspects of a person's childhood family are correlated or not with their career or family choices as an adult. Or how political or religious affiliations correlate with drug use or sexual practices. It's an extremely wide-ranging survey.
#
# Feel free to work with other people in groups, and ask questions!

# %% [markdown]
# ## 1. Variables and Why
#
# The variables I decided to choose for mine was:
# * year
# * occupation
# * industry
# * web usage
# * computer usage
# * happiness
# * relationship happiness
#
# The questions I thought of asking here was the question of correlation. Is computer usage correlated with relationship happiness or general happiness. There's the narrative now-a-days that say high computer usage is extremely detrimental to a person's happiness. That is a causal narrative that X computer usage leads to Y unhappiness, but I'm moreso just looking to confirm the correlation fact rather than the causal fact. It might just be that people who are unhappy are because of their environmental factors and by circumstance really have nothing better to than, so they spend their time on the internet. I also want to observe the counterfactual of people who use a lot of the internet and are actaully happy.
#
# Another question that I want to answer then is similarly how related thta is to relationship happiness. Something like if you are on the internet too much that makes you spend less time with your partner, therefore computer usage leads to unhappiness in relationships. But, the interesting thing is again the counterfactual, computer usage leading to happiness in a relationship. This could be the case if 1. the person was talking to an ai boy/girlfriend or 2. it is a long distance relationship. I don't know if chatbots were widely available or they have more recent data on that, but it would be something interest to look at and see if it exists.
#
# I added industry and occupation on to there because it would make sense to split-up or segment by occupation or job. A person that works in IT would probably be happy using a computer all the time because they get paid to do so. I am moreso interested in the case of "leisurely" usage of the internet, which is web/computer usage in someones free-time in relation to the other variables. Also, the pressupossition here is that even then IT workers also enjoy computer science as a hobby and will obviously be happy correlated with computer usage. Although, there can be hardcore hobbyists or lonely people that work in different industries.

# %% [markdown]
# ## 2. Clean-up

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("data/GSS.xlsx")
df.head(1)
# Out:
#    year  id_                                              occ10  \
# 0  1972    1  Wholesale and retail buyers, except farm products
#
#            indus10          happy           hapcohab            compuse  \
# 0  Clothing stores  Not too happy  .i:  Inapplicable  .i:  Inapplicable
#
#                wwwhr             ballot
# 0  .i:  Inapplicable  .i:  Inapplicable

# %%
def no_answer(string):
    if string == ".i:  Inapplicable":
        return True
    elif string == ".n:  No answer":
        return True
    elif string == ".d:  Do not Know/Cannot Choose":
        return True
    elif string == ".s:  Skipped on Web":
        return True
    return False

# only drop in happy and uses internet to see if results change
print(df.shape)
df = df[~df["happy"].map(no_answer)]
df = df[~df["wwwhr"].map(no_answer)]
print(df.shape)

# uncomment out for same results but with people in a relationship
# print(df.shape)
# df = df[~df.map(no_answer).any(axis=1)] # drop any row that skipped answering the questions
# print(df.shape)

# check for any more cleaning
print(df.isna().sum())
# Out:
# (72390, 9)
# (15450, 9)
# year        0
# id_         0
# occ10       0
# indus10     0
# happy       0
# hapcohab    0
# compuse     0
# wwwhr       0
# ballot      0
# dtype: int64

# %%
df.dtypes
# Out:
# year         int64
# id_          int64
# occ10       object
# indus10     object
# happy       object
# hapcohab    object
# compuse     object
# wwwhr       object
# ballot      object
# dtype: object

# %%
for i in range(df.shape[1]):
    print(pd.unique(df.iloc[:,i])) # found that wwwhr took "other" so i need to clean that
# Out:
# [2000 2002 2004 2006 2010 2012 2014 2016 2018 2021 2022]
# [   1    4    5 ... 3541 3542 3543]
# ['Broadcast and sound engineering technicians and radio' 'Veterinarians'
#  'Air traffic controllers and airfield operations specialists'
#  'Sales and related workers, all other'
#  'First-line supervisors of office and administrative support workers'
#  'Accountants and auditors' 'Education administrators'
#  'Computer systems analysts' 'Janitors and building cleaners'
#  'Marketing and sales managers' '.n:  No answer'
#  'General and operations managers' 'Secondary school teachers'
#  '.i:  Inapplicable'
#  'Claims adjusters, appraisers, examiners, and investigators' 'Announcers'
#  'Computer and information systems managers'
#  'Office and administrative support workers, all other'
#  'Waiters and waitresses' 'Personal care aides'
#  'Secretaries and administrative assistants' 'Financial managers'
#  'Retail salespersons' 'Word processors and typists'
#  'Other education, training, and library workers'
#  'Advertising and promotions managers' 'Cashiers'
#  'Elementary and middle school teachers'
#  'Nursing, psychiatric, and home health aides'
#  'Reservation and transportation ticket agents and travel clerks'
#  'Parking lot attendants'
#  'Inspectors, testers, sorters, samplers, and weighers'
#  'Driver/sales workers and truck drivers'
#  'Heating, air conditioning, and refrigeration mechanics and installers'
#  'Web developers' 'Mechanical engineers'
#  'Industrial engineers, including health and safety' 'Electricians'
#  'Physical therapists'
#  'Property, real estate, and community association managers'
#  'Musicians, singers, and related workers' 'Teacher assistants'
#  'Customer service representatives'
#  'Automotive service technicians and mechanics' 'Managers, all other'
#  'Eligibility interviewers, government programs' 'Dishwashers'
#  'Chief executives' 'Brickmasons, blockmasons, and stonemasons'
#  'Explosives workers, ordnance handling experts, and blasters'
#  'Artists and related workers' 'Childcare workers'
#  'Software developers, applications and systems software'
#  'Network and computer systems administrators'
#  'Real estate brokers and sales agents' 'Personal financial advisors'
#  'Industrial production managers' 'Social and community service managers'
#  'Social workers' 'Computer programmers' 'Postsecondary teachers'
#  'Statistical assistants' 'Management analysts' 'Designers'
#  'Administrative services managers' 'Tellers'
#  'Reinforcing iron and rebar workers'
#  'Hairdressers, hairstylists, and cosmetologists'
#  'Speech-language  pathologists' 'Construction managers'
#  'Paralegals and legal assistants'
#  'Computer, automated teller, and office machine repairers'
#  'Public relations specialists' 'Training and development specialists'
#  'First-line supervisors of construction trades and extraction workers'
#  "Police and sheriff's patrol officers"
#  'First-line supervisors of production and operating workers'
#  'Dispatchers' 'Technical writers' 'Data entry keyers'
#  'Other teachers and instructors'
#  'Securities, commodities, and financial services sales agents'
#  'Bookkeeping, accounting, and auditing clerks' 'Counselors'
#  'Health practitioner support technologists and technicians'
#  'Statisticians'
#  'First-line supervisors of food preparation and serving workers'
#  'Operating engineers and other construction equipment  operators'
#  'Electric motor, power tool, and related repairers' 'Flight attendants'
#  'First-line supervisors of retail sales workers'
#  'Dining room and cafeteria attendants and bartender helpers'
#  'Weighers, measurers, checkers, and samplers, recordkeeping'
#  'Sheet metal workers' 'Registered nurses'
#  'Preschool and kindergarten teachers'
#  'Sales representatives,  wholesale and manufacturing'
#  'News analysts, reporters and correspondents'
#  'First-line supervisors of non-retail sales workers'
#  'Human resources workers' 'Psychologists'
#  'Photographic process workers and processing machine operators'
#  'Diagnostic related technologists and technicians'
#  'Financial specialists, all other' 'Computer support specialists'
#  'Budget analysts' 'Medical assistants'
#  'Maintenance and repair workers, general' 'Loan interviewers and clerks'
#  'Stock clerks and order fillers'
#  'Security guards and gaming surveillance officers' 'Optometrists'
#  'Telemarketers' 'Interviewers, except eligibility and loan'
#  'Shipping, receiving, and traffic clerks' 'Gaming services workers'
#  'Medical and health services managers' 'Payroll and timekeeping clerks'
#  'Lawyers' 'Agents and business managers of artists, performers,'
#  'Computer operators' 'Office clerks, general'
#  'Carpet, floor, and tile installers and finishers'
#  'Pipelayers, plumbers, pipefitters, and steamfitters'
#  'First-line supervisors of protective service workers, all other'
#  'Construction laborers'
#  'First-line supervisors of mechanics, installers, and repairers'
#  'Fish and game wardens'
#  'Combined food preparation and serving workers, including fast food'
#  'Laborers and freight, stock, and material movers, hand'
#  'First-line supervisors of police and detectives'
#  'Special education teachers' 'Therapists, all other' 'Librarians'
#  'Food service managers' 'Emergency management directors'
#  'Farmers, ranchers, and other agricultural managers'
#  'Appraisers and assessors of real estate'
#  'Engineering technicians, except drafters' 'Food preparation workers'
#  'Print binding and finishing workers'
#  'Health diagnosing and treating practitioners, all other'
#  'Electrical and electronics engineers'
#  'Wholesale and retail buyers, except farm products' 'Clergy'
#  'Telecommunications  line installers and repairers'
#  'Library assistants, clerical'
#  'Automotive glass installers and repairers'
#  'Licensed practical and licensed vocational nurses'
#  'Animal control workers' 'Maids and housekeeping cleaners'
#  'Sewing machine operators' 'Upholsterers' 'Chemical engineers'
#  'Receptionists and information clerks'
#  'Miscellaneous healthcare support occupations, including medical equipment preparers'
#  'Electrical, electronics, and electromechanical assemblers'
#  'Producers and directors' 'Bailiffs, correctional officers, and jailers'
#  'Roofers' 'Civil engineers' 'Production workers, all other'
#  'Sales representatives, services, all other'
#  'Computer and information research scientists'
#  'Welding, soldering, and brazing workers'
#  'Cleaners of vehicles and equipment' 'Firefighters'
#  'Miscellaneous agricultural workers' 'Taxi drivers and chauffeurs'
#  'Miscellaneous assemblers and fabricators' 'Food servers, nonrestaurant'
#  'Market research analysts and marketing specialists' 'Dentists'
#  'Architects, except naval' 'Emergency medical technicians and paramedics'
#  'Packers and packagers, hand'
#  'Clinical laboratory technologists and technicians'
#  'Miscellaneous legal support workers'
#  'Grinding, lapping, polishing, and buffing machine tool setters,  operators, and tenders, metal and plastic'
#  'Grounds maintenance workers'
#  'Television, video, and motion picture camera operators and'
#  'Compensation, benefits, and job analysis specialists'
#  'Construction and building inspectors' 'Prepress technicians and workers'
#  'Insurance sales agents'
#  'Athletes, coaches, umpires, and related workers' 'Bartenders'
#  'Postal service clerks' 'Insurance claims and policy processing clerks'
#  'Billing and posting clerks' 'Editors'
#  'Credit counselors and loan officers'
#  'Transportation, storage, and distribution managers'
#  'Stationary engineers and boiler operators'
#  'Hosts and hostesses, restaurant, lounge, and coffee shop'
#  'Miscellaneous life, physical, and social science technicians'
#  'Agricultural and food science technicians'
#  'First-line enlisted military supervisors'
#  'Butchers and other meat, poultry, and fish processing workers'
#  'Purchasing agents, except wholesale, retail, and farm products'
#  'Purchasing managers'
#  'First-line supervisors of personal service workers' 'Cooks'
#  'Physicians and surgeons' 'Tailors, dressmakers, and sewers'
#  'Chefs and head cooks' 'Architectural and engineering managers'
#  'Detectives and criminal investigators'
#  'Business operations specialists, all other' 'Machinists'
#  'Water and wastewater treatment plant and system operators'
#  'Production, planning, and expediting clerks'
#  'Information security analysts' 'Computer network architects'
#  'Industrial truck and tractor operators' 'Paperhangers'
#  'Dental assistants' 'Bakers' 'Surveying and mapping technicians'
#  'Mail clerks and mail machine operators, except postal service'
#  'Painting workers'
#  'Medical, dental, and ophthalmic laboratory technicians'
#  'Painters, construction and maintenance' 'Printing press operators'
#  'File Clerks' 'Postal service mail carriers'
#  'Miscellaneous health technologists and technicians'
#  'Advertising sales agents' 'Miscellaneous personal appearance workers'
#  'Dietitians and nutritionists' 'Human resources managers'
#  'Operations research analysts' 'Bus drivers'
#  'Archivists, curators, and museum technicians'
#  'Miscellaneous entertainment attendants and related workers'
#  'Parts salespersons' 'Carpenters' 'Machine feeders and offbearers'
#  'Veterinary assistants and laboratory animal caretakers'
#  'Opticians, dispensing'
#  'Bus and truck mechanics and diesel engine specialists'
#  'Cutting, punching, and press machine setters, operators, and tenders, metal and plastic'
#  'Computer hardware engineers' 'Telephone operators'
#  'Credit authorizers, checkers, and clerks' 'Massage therapists'
#  'Engine and other machine assemblers'
#  'Motor vehicle operators, all other' 'Transportation inspectors'
#  'Information and record clerks, all other' 'Tax preparers'
#  'Procurement clerks' 'Engineers, all other' 'Millwrights'
#  'Heavy vehicle and mobile equipment service technicians and mechanics'
#  'Medical transcriptionists' 'Travel agents'
#  'Chemists and materials scientists'
#  'Judges, magistrates, and other judicial workers'
#  'Supervisors of transportation and material moving workers'
#  'Surveyors, cartographers, and photogrammetrists'
#  'Elevator installers and repairers'
#  'Electrical power-line installers and repairers'
#  'Aircraft pilots and flight engineers' 'Fundraisers'
#  'Other extraction workers' 'Miscellaneous plant and system operators'
#  'Bill and account collectors' 'Respiratory therapists'
#  'Cargo and freight agents' 'Baggage porters, bellhops, and concierges'
#  'Physical scientists, all other' 'Chemical technicians'
#  'Small engine mechanics'
#  'Door-to-door sales workers, news and street vendors, and related workers'
#  'Chiropractors' 'Physical therapist assistants and aides'
#  'Probation officers and correctional treatment specialists'
#  'Chemical processing machine setters, operators, and tenders'
#  'Nonfarm animal caretakers' 'Insurance underwriters'
#  'Occupational therapy assistants and aides'
#  'Environmental scientists and geoscientists' 'Correspondence clerks'
#  'Military enlisted tactical operations and air/weapons specialists and crew members'
#  'Drafters' 'Food processing workers, all other'
#  'Woodworking machine setters, operators, and tenders, except sawing'
#  'Buyers and purchasing agents, farm products' 'Glaziers' 'Actuaries'
#  'Extruding and drawing machine setters, operators, and tenders,  metal and plastic'
#  'Geological and petroleum technicians'
#  'Compensation and benefits managers'
#  'Metal workers and plastic workers, all other'
#  'Urban and regional planners'
#  'Industrial and refractory machinery mechanics' 'Pharmacy aides'
#  'Recreational therapists' 'Earth drillers, except oil and gas'
#  'First-line supervisors of fire fighting and prevention workers'
#  'Tool and die makers'
#  'Sawing machine setters, operators, and tenders, wood'
#  'Miscellaneous construction and related workers' 'Writers and authors'
#  'Photographers' 'Office machine operators, except computer'
#  'Animal trainers' 'Lodging managers' 'Pest control workers'
#  'Automotive and watercraft service attendants' 'Occupational therapists'
#  'Hotel, motel, and resort desk clerks'
#  'Training and development managers'
#  'Jewelers and precious stone and metal workers'
#  'Computer occupations, all other' 'Judicial law clerks'
#  'Religious workers, all other'
#  'Radio and telecommunications equipment installers and repairers'
#  'Woodworkers, all other'
#  'Power plant operators, distributors, and dispatchers'
#  'Molders and molding machine setters, operators, and tenders, metal and plastic'
#  'Couriers and messengers' 'Automotive body and related repairers'
#  'Gaming managers'
#  'Miscellaneous community and social service specialists,'
#  'Other transportation workers'
#  'Medical records and health information technicians' 'Legislators'
#  'Pharmacists' 'Meeting, convention, and event planners' 'Mathematicians'
#  'Derrick, rotary drill, and service unit operators, oil, gas, and mining'
#  'Electrical and electronics repairers, industrial and utility'
#  'First-line supervisors of landscaping, lawn service, and groundskeeping workers'
#  'Social science research assistants' 'Locksmiths and safe repairers'
#  'Entertainers and performers, sports and related workers, all other'
#  'Cost estimators'
#  'Human resources assistants, except payroll and timekeeping'
#  'Counter attendants, cafeteria, food concession, and coffee shop'
#  'Database administrators' 'Cabinetmakers and bench carpenters'
#  'Phlebotomists' 'First-line supervisors of correctional officers'
#  'Aerospace engineers' 'Laundry and dry-cleaning workers'
#  'Extruding, forming, pressing, and compacting machine setters,'
#  'Postal service mail sorters, processors, and processing  machine operators'
#  'Milling and planing machine setters, operators, and tenders, metal  and plastic'
#  'Logging workers' 'Compliance officers' 'Recreation and fitness workers'
#  'Metal furnace operators, tenders, pourers, and casters'
#  'Sales engineers' 'Avionics technicians' 'Crossing guards'
#  'Crushing, grinding, polishing, mixing, and blending workers'
#  'Marine engineers and naval architects'
#  'Miscellaneous social scientists and related workers'
#  'Nurse anesthetists' 'Military, rank not specified' 'Library technicians'
#  'Biological scientists'
#  'Drywall installers, ceiling tile installers, and tapers'
#  'Dental hygienists'
#  'First-line supervisors of housekeeping and janitorial workers'
#  'Logisticians' 'Fishers and related fishing workers'
#  'Public relations and fundraising managers'
#  'Postmasters and mail superintendents'
#  'Tax examiners and collectors, and revenue agents'
#  'Private detectives and investigators'
#  'Locomotive engineers and operators'
#  'Conservation scientists and foresters'
#  'Military officer special and tactical operations leaders'
#  'Fire inspectors' 'Other installation, maintenance, and repair workers'
#  'Petroleum engineers'
#  'Packaging and filling machine operators and tenders'
#  'Coin, vending, and amusement machine servicers and repairers'
#  'Electronic home entertainment equipment installers and repairers'
#  'Podiatrists' 'Financial analysts'
#  'Refuse and recyclable material collectors' 'Environmental engineers'
#  'Physician assistants' 'Order clerks'
#  'Lifeguards and other recreational, and all other protective service workers'
#  'Mine shuttle car operators'
#  'Directors, religious activities and education' 'Cutting workers'
#  'Pressers, textile, garment, and related materials' 'Medical scientists'
#  'Furniture finishers' 'Precision instrument and equipment repairers'
#  'Biological technicians'
#  'First-line supervisors of farming, fishing, and forestry workers'
#  'Structural metal fabricators and fitters'
#  'Models, demonstrators, and product promoters' 'Residential advisors'
#  'Barbers' 'Nurse practitioners'
#  'Switchboard operators, including answering service'
#  'Transportation attendants, except flight attendants'
#  'Aircraft mechanics and service technicians' 'Credit analysts'
#  'Molders, shapers, and casters, except metal and plastic'
#  'Miscellaneous vehicle and mobile equipment mechanics, installers, and repairers'
#  'Helpers, construction trades' 'Pumping station operators'
#  'Court, municipal, and license clerks' 'Agricultural and food scientists'
#  'Radiation therapists' 'Ushers, lobby attendants, and ticket takers'
#  'Meter readers, utilities' 'Railroad conductors and yardmasters'
#  'Boilermakers' 'Hazardous materials removal workers'
#  'Mining machine operators' 'Forest and conservation workers' 'Economists'
#  'Miscellaneous media and communication  workers'
#  'Food and tobacco roasting, baking, and drying machine operators and tenders'
#  'Structural iron and steel workers' 'Financial clerks, all other'
#  'Sailors and marine oilers' 'Motion picture projectionists'
#  'Agricultural inspectors'
#  'Mining and geological engineers, including mining safety engineers'
#  'Counter and rental clerks' 'Crane and tower operators'
#  'Heat treating equipment setters, operators, and tenders, metal and plastic'
#  'Septic tank servicers and sewer pipe cleaners'
#  'Social and human service assistants' 'Nuclear engineers'
#  'Other healthcare practitioners and technical occupations'
#  'Paper goods machine setters, operators, and tenders'
#  'Rolling machine setters, operators, and tenders, metal and plastic'
#  'Home appliance repairers' 'Brokerage clerks' 'Insulation workers'
#  'Materials engineers' 'Food batchmakers'
#  'Cement masons, concrete finishers, and terrazzo workers'
#  'Helpers, production workers'
#  'Personal care and service workers, all other'
#  'Communications  equipment operators, all other' 'Financial examiners'
#  'Aircraft structure, surfaces, rigging, and systems assemblers'
#  'Dredge, excavating, and loading machine operators'
#  'Shoe machine operators and tenders' 'Atmospheric and space scientists'
#  'Helpers, installation, maintenance, and repair workers'
#  'Morticians, undertakers, and funeral directors'
#  'Security and fire alarm systems installers' 'Dancers and choreographers'
#  'Electronic equipment installers and repairers, motor vehicles'
#  'Material moving workers, all other' 'Tire builders'
#  'Graders and sorters, agricultural products' 'Etchers and engravers'
#  'Tour and travel guides' 'Control and valve installers and repairers'
#  '.u:  Uncodable' 'New accounts clerks' 'Funeral service managers'
#  'Roustabouts, oil and gas' 'First-line supervisors of gaming workers'
#  'Computer control programmers and operators'
#  'Highway maintenance workers'
#  'Miscellaneous mathematical science occupations' '.s:  Skipped on Web'
#  'Maintenance workers, machinery' 'Nurse midwives'
#  'Tool grinders, filers, and sharpeners' 'Agricultural engineers'
#  'Biomedical engineers' 'Hunters and trappers'
#  'Subway, streetcar, and other rail transportation workers'
#  '    operators, and tenders Furnace, kiln, oven, drier, and kettle operators and tenders'
#  'Actors' 'Exercise physiologists' 'Survey researchers'
#  'Ambulance drivers and attendants, except emergency medical  technicians'
#  'Audiologists' 'Shoe and leather workers and repairers'
#  'Natural sciences managers'
#  'Textile, apparel, and furnishings workers, all other'
#  'Food cooking machine operators and tenders'
#  'Railroad brake, signal, and switch operators' 'Fence erectors' 'Riggers'
#  'Rail-track laying and maintenance equipment operators'
#  'Gaming cage workers']
# ['Radio and television broadcasting and cable subscription programming'
#  'Veterinary services' 'Scientific research and development services'
#  'Miscellaneous retail stores'
#  'Computer systems design and related services'
#  'Accounting, tax preparation, bookkeeping, and payroll services'
#  'Colleges and universities, including junior colleges'
#  'Petroleum and petroleum products, merchant wholesalers' 'Hospitals'
#  'Sporting goods, camera, and hobby and toy stores'
#  'Industrial and miscellaneous chemicals' 'Automobile dealers'
#  'Elementary and secondary schools' '.i:  Inapplicable'
#  'Insurance carriers and related activities'
#  'Drinking places, alcoholic beverages'
#  'Management, scientific, and technical consulting services'
#  'Individual and family services' 'Restaurants and other food services'
#  'Other personal services'
#  'Data processing, hosting, and related services'
#  'Automotive equipment rental and leasing' 'Music stores' '.n:  No answer'
#  'Other direct selling establishments'
#  'Building material and supplies dealers' 'Clothing stores'
#  'Air transportation' 'Pharmaceutical and medicine manufacturing'
#  'Lumber and other construction materials, merchant wholesalers'
#  'Construction' 'Motor vehicles and motor vehicle equipment manufacturing'
#  'Natural gas distribution' 'Waste management and remediation services'
#  'Securities, commodities, funds, trusts, and other financial investments'
#  'Legal services' 'Real estate'
#  'Independent artists, performing arts, spectator sports, and related industries'
#  'Periodical, book, and directory publishers'
#  'Banking and related activities'
#  'Administration of human resource programs'
#  'Investigation and security services'
#  'Executive offices and legislative bodies'
#  'Printing and related support activities' 'Child day care services'
#  'Computer and peripheral equipment manufacturing'
#  'Architectural, engineering, and related services'
#  'Non-depository credit and related activities'
#  'Not specified food industries' 'Cut and sew apparel manufacturing'
#  'Electronic shopping' 'Business support services'
#  'Electronic component and product manufacturing, n.e.c.'
#  'Sporting and athletic goods, and doll, toy and game manufacturing'
#  'Beauty salons' 'Wired telecommunications carriers' 'Employment services'
#  'Furniture and home furnishings stores'
#  'Other professional, scientific, and technical services'
#  'Advertising and related services' 'Home health care services'
#  'Vocational rehabilitation services'
#  'Justice, public order, and safety activities'
#  'Plastics product manufacturing' 'Gasoline stations'
#  'Museums, art galleries, historical sites, and similar institutions'
#  'Services incidental to transportation'
#  'Department stores and discount stores'
#  'Other schools and instruction, and educational support services'
#  'Outpatient care centers'
#  'Machinery, equipment, and supplies, merchant wholesalers'
#  'Newspaper publishers' 'Traveler accommodation'
#  'Radio, TV, and computer stores'
#  'Iron and steel mills and steel product manufacturing' 'Grocery stores'
#  'Motor vehicles, parts and supplies, merchant wholesalers'
#  'Motion pictures and video industries'
#  'Offices of other health practitioners'
#  'Construction, and mining and oil and gas field machinery manufacturing'
#  'Electronic and precision equipment repair and maintenance'
#  'Other health care services'
#  'Residential care facilities, without nursing' 'Software publishers'
#  'Offices of optometrists'
#  'Administration of economic programs and space research'
#  'Public finance activities' 'Couriers and messengers'
#  'Not specified retail trade' 'Gift, novelty, and souvenir shops'
#  'Private households' 'Sound recording industries'
#  'Commercial and service industry machinery manufacturing'
#  'Business, technical, and trade schools and training'
#  'Fishing, hunting, and trapping' 'Specialty food stores'
#  'Resin, synthetic rubber and fibers, and filaments manufacturing'
#  'Drycleaning and laundry services' 'Animal slaughtering and processing'
#  'Offices of dentists' 'Mail order houses' 'Household appliance stores'
#  'Auto parts, accessories, and tire stores' 'Animal production'
#  'Electric power generation, transmission, and distribution'
#  'Seafood and other miscellaneous foods, n.e.c.' 'U.S. Army'
#  'Other telecommunications services' 'Religious organizations'
#  'Other administrative and other support services'
#  'Electrical lighting and electrical equipment manufacturing, and other electrical component manufacturing, n.e.c.'
#  'Apparel, fabrics, and notions, merchant wholesalers'
#  'Communications, and audio and video equipment manufacturing'
#  'Not specified manufacturing industries' 'Libraries and archives'
#  'Offices of physicians'
#  'Cement, concrete, lime, and gypsum product manufacturing'
#  'Textile and fabric finishing and coating mills'
#  'Furniture and home furnishing, merchant wholesalers'
#  'Furniture and related product manufacturing' 'Oil and gas extraction'
#  'Services to buildings and dwellings' 'Rail transportation'
#  'Warehousing and storage' 'Automotive repair and maintenance'
#  'Health and personal care, except drug, stores'
#  'Paperboard containers and boxes'
#  'Animal food, grain, and oilseed milling' 'Petroleum refining'
#  'Truck transportation' 'Prefabricated wood buildings and mobile homes'
#  'Landscaping services' 'Glass and glass product manufacturing'
#  'Specialized design services'
#  'National security and international affairs'
#  'Aerospace product and parts manufacturing'
#  'Aircraft and parts manufacturing'
#  'Commercial and industrial machinery and equipment repair and maintenance'
#  'Savings institutions, including credit unions'
#  'Business, professional, political, and similar organizations'
#  'Postal Service'
#  'Professional and commercial equipment and supplies, merchant wholesalers'
#  'Other amusement, gambling, and recreation industries'
#  'Miscellaneous fabricated metal products manufacturing'
#  'Nursing care facilities'
#  'Paper and paper products, merchant wholesalers' 'U.S. Air Force'
#  'Recyclable material, merchant wholesalers'
#  'Alcoholic beverages, merchant wholesalers'
#  'Machinery manufacturing, n.e.c.'
#  'Travel arrangements and reservation services'
#  'Groceries and related products, merchant wholesalers'
#  'Office supplies and stationery stores'
#  'Machine shops; turned product; screw, nut, and bolt manufacturing'
#  'Water, steam, air-conditioning, and irrigation systems'
#  'Electric and gas, and other combinations' 'Book stores and news dealers'
#  'Agricultural chemical manufacturing'
#  'Navigational, measuring, electromedical, and control instruments manufacturing'
#  'Pharmacies and drug stores'
#  'Civic, social, advocacy organizations, and grantmaking and giving services'
#  'Coating, engraving, heat treating and allied activities'
#  'Aluminum production and processing'
#  'Miscellaneous petroleum and coal products'
#  'Drugs, sundries, and chemical and allied products, merchant wholesalers'
#  'Medical equipment and supplies manufacturing'
#  'Miscellaneous manufacturing, n.e.c.'
#  'Structural metals, and boiler, tank, and shipping container manufacturing'
#  'Hardware, plumbing and heating equipment, and supplies, merchant wholesalers'
#  'Sewing, needlework, and piece goods stores'
#  'Community food and housing, and emergency services'
#  'Bus service and urban transit' 'Retail bakeries'
#  'Not specified type of mining'
#  'Lawn and garden equipment and supplies stores' 'Labor unions'
#  'Other motor vehicle dealers' 'Foundries' 'Hardware stores'
#  'Support activities for agriculture and forestry' 'Crop production'
#  'Retail florists' 'Rubber product, except tire, manufacturing'
#  'Miscellaneous nonmetallic mineral product manufacturing'
#  'Recreational vehicle parks and camps, and rooming and boarding houses'
#  'Nail salons and other personal care services'
#  'Other general government and support'
#  'Household appliance manufacturing'
#  'Administration of environmental quality and housing programs'
#  'Nonmetallic mineral mining and quarrying'
#  'Veneer, plywood, and engineered wood products'
#  'Structural clay product manufacturing' 'Not specified utilities'
#  'Fruit and vegetable preserving and specialty food manufacturing'
#  'Miscellaneous paper and pulp products'
#  'Miscellaneous general merchandise stores'
#  'Pulp, paper, and paperboard mills' 'Other information services'
#  'Commercial, industrial, and other intangible assets rental and leasing'
#  'Wholesale electronic markets, agents and brokers'
#  'Jewelry, luggage, and leather goods stores' 'Offices of chiropractors'
#  'Support activities for mining' 'Dairy product manufacturing'
#  'Engines, turbines, and power transmission equipment manufacturing'
#  'Soap, cleaning compound, and cosmetics manufacturing'
#  'Internet publishing and broadcasting and web search portals'
#  'Metals and minerals, except petroleum, merchant wholesalers'
#  'Ship and boat building' 'Forestry, except logging'
#  'Miscellaneous nondurable goods, merchant wholesalers'
#  'Not specified wholesale trade' 'U.S. Armed Forces/n.s.' 'U.S. Navy'
#  'Knitting fabric mills, and apparel knitting mills'
#  'Electrical and electronic goods, merchant wholesalers' 'Shoe stores'
#  'Miscellaneous wood products' 'Agricultural implement manufacturing'
#  'Beer, wine, and liquor stores' 'Fabric mills, except knitting mills'
#  'Cutlery and hand tool manufacturing' 'Not specified metal industries'
#  'Bakeries, except retail' 'Used merchandise stores'
#  'Footwear and leather goods repair' 'Tobacco manufacturing'
#  'Sewage treatment facilities' 'Metalworking machinery manufacturing'
#  'Car washes' 'Taxi and limousine service'
#  'Scenic and sightseeing transportation'
#  'Management of companies and enterprises' 'U.S. Marine Corps'
#  'Other transportation equipment manufacturing'
#  'Funeral homes, and cemeteries and crematories'
#  'Miscellaneous durable goods, merchant wholesalers'
#  'Beverage manufacturing'
#  'Personal and household goods repair and maintenance'
#  'Textile product mills, except carpet and rug' 'U.S. Coast Guard'
#  'Electronic auctions' 'Pipeline transportation' 'Barber shops'
#  'Vending machine operators' 'Railroad rolling stock manufacturing'
#  'Active duty military personnel, all other'
#  'Sawmills and wood preservation' 'Video tape and disk rental' 'Ordnance'
#  'Metal ore mining' 'Coal mining' 'Water transportation' 'Fuel dealers'
#  'Other consumer goods rental' 'Tire manufacturing' 'Bowling centers'
#  'Logging' 'Sugar and confectionery products'
#  'Nonferrous metal (except aluminum) production and processing'
#  'Farm product raw materials, merchant wholesalers'
#  'Paint, coating, and adhesive manufacturing'
#  'Farm supplies, merchant wholesalers' 'Footwear manufacturing'
#  'Pottery, ceramics, and plumbing fixture manufacturing'
#  'Not specified machinery manufacturing'
#  'Apparel accessories and other apparel manufacturing'
#  'Metal forgings and stampings' '.s:  Skipped on Web'
#  'Carpet and rug mills' 'Fiber, yarn, and thread mills']
# ['Pretty happy' 'Very happy' 'Not too happy']
# ['.i:  Inapplicable' 'Very happy' 'Pretty happy' 'Not too happy'
#  '.n:  No answer']
# ['YES' 'NO' '.i:  Inapplicable' '.s:  Skipped on Web'
#  '.d:  Do not Know/Cannot Choose']
# ['5' '2' '1' '0 hours' '6' '7' '3' '4' '30' '10' '50' '21' '23' '40' '8'
#  '12' '20' '16' '15' '60' '14' '25' '46' '9' '17' '13' '98' '28' '42' '35'
#  '45' '36' '32' '112' '22' '24' '11' '64' '29' '48' '27' '26' '130' '100'
#  '72' '55' '80' '70' '18' '75' '65' '168 hours' '66' '120' '38' '19' '84'
#  '63' '33' '122' '90' '91' '132' '49' '85' '140' '37' '86' '34' '56' '47'
#  '43' '105' '95' '83' '57' '68' '125' '110' '150' '160' '39' '96' '54'
#  '76' '51' '119' '41' '126']
# ['Ballot a' 'Ballot b' 'Ballot c']

# %%
df['wwwhr'] = df['wwwhr'].apply(lambda x: x.replace("hours", "") if "hours" in x else x)
df['wwwhr'] = pd.to_numeric(df['wwwhr'])

# %%
df = df[~df["wwwhr"] == 0] # remove if you don't use the inter

# %% [markdown]
# ## 3. Exploration

# %%
for i in range(df.shape[1]):
    print(pd.Series(df.iloc[:,i]).value_counts()) # found that wwwhr took "other" so i need to clean that
    print("=" * 20)
# Out:
# year
# 2021    211
# 2022    197
# 2016    142
# 2018    141
# 2014    125
# 2012     91
# Name: count, dtype: int64
# ====================
# id_
# 496     3
# 726     3
# 2397    3
# 1193    3
# 71      3
#        ..
# 2311    1
# 2352    1
# 2372    1
# 2388    1
# 2004    1
# Name: count, Length: 820, dtype: int64
# ====================
# occ10
# Retail salespersons                                                    23
# Nursing, psychiatric, and home health aides                            21
# Cooks                                                                  20
# First-line supervisors of office and administrative support workers    18
# Cashiers                                                               18
#                                                                        ..
# Gaming cage workers                                                     1
# Brickmasons, blockmasons, and stonemasons                               1
# Geological and petroleum technicians                                    1
# Aircraft mechanics and service technicians                              1
# Respiratory therapists                                                  1
# Name: count, Length: 263, dtype: int64
# ====================
# indus10
# Construction                                                    73
# Restaurants and other food services                             63
# Elementary and secondary schools                                43
# Hospitals                                                       30
# Colleges and universities, including junior colleges            24
#                                                                 ..
# Business, professional, political, and similar organizations     1
# Funeral homes, and cemeteries and crematories                    1
# Not specified machinery manufacturing                            1
# Aluminum production and processing                               1
# Cement, concrete, lime, and gypsum product manufacturing         1
# Name: count, Length: 180, dtype: int64
# ====================
# happy
# Pretty happy     528
# Very happy       275
# Not too happy    104
# Name: count, dtype: int64
# ====================
# hapcohab
# Very happy       521
# Pretty happy     348
# Not too happy     38
# Name: count, dtype: int64
# ====================
# compuse
# YES    808
# NO      99
# Name: count, dtype: int64
# ====================
# wwwhr
# 10     80
# 2      73
# 20     69
# 1      67
# 5      58
# 0      58
# 3      49
# 15     48
# 4      45
# 40     43
# 30     37
# 8      37
# 7      29
# 6      29
# 25     20
# 12     19
# 50     18
# 14     18
# 60     14
# 35     12
# 21     12
# 80      7
# 9       6
# 28      6
# 70      6
# 16      5
# 24      4
# 100     3
# 120     3
# 36      3
# 42      2
# 72      2
# 22      2
# 45      2
# 63      1
# 18      1
# 26      1
# 17      1
# 84      1
# 83      1
# 65      1
# 57      1
# 56      1
# 90      1
# 130     1
# 54      1
# 23      1
# 76      1
# 13      1
# 41      1
# 32      1
# 48      1
# 96      1
# 168     1
# 150     1
# Name: count, dtype: int64
# ====================
# ballot
# Ballot a    464
# Ballot b    443
# Name: count, dtype: int64
# ====================

# %%
fig, ax = plt.subplots(1,2,figsize=(12,5))
df["log_wwwhr"] = np.log(df["wwwhr"])

sns.histplot(data=df, x="log_wwwhr",ax=ax[0])
order = ["Pretty happy", "Very happy", "Not too happy"]
lines = ["--",":","-"] # dashed = happy, dotted = yay, 
sns.countplot(data=df, x="happy", ax=ax[1], order=order)

for level,line in zip(order,lines):
    print(level,line)
    level_mean = df[df["happy"] == level]["log_wwwhr"].mean()
    level_median = df[df["happy"] == level]["log_wwwhr"].median()
    level_max = df[df["happy"] == level]["log_wwwhr"].max()
    ax[0].axvline(level_mean, linestyle=line, color="b", label=f"{level} mean")
    ax[0].axvline(level_median, linestyle=line, color="g", label=f"{level} median")
    print(level_max)
    ax[0].axvline(level_max, linestyle=line, color="r", label=f"{level} max")

ax[0].legend(loc="upper right")
# Out:
# Pretty happy --
# 5.123963979403259
# Very happy :
# 5.123963979403259
# Not too happy -
# 5.123963979403259
# /home/henry/Git/ds-3001/local_venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df[df["log_wwwhr"] == 5.123963979403259] # computer usage isn't related to happyness, its probably your career than anything
# Out:
#        year   id_                                              occ10  \
# 53232  2010   190                        Computer network architects
# 55820  2012   734  Market research analysts and marketing special...
# 60620  2016  1022                             Waiters and waitresses
# 67489  2021  2947  Computer, automated teller, and office machine...
# 71155  2022  2310                                              Cooks
# 71192  2022  2347                                       Order clerks
# 71963  2022  3118                   Customer service representatives
#
#                                                  indus10          happy  \
# 53232  Motor vehicles and motor vehicle equipment man...   Pretty happy
# 55820  Other professional, scientific, and technical ...     Very happy
# 60620                Restaurants and other food services  Not too happy
# 67489  Internet publishing and broadcasting and web s...   Pretty happy
# 71155                Restaurants and other food services     Very happy
# 71192        National security and international affairs     Very happy
# 71963                                     Grocery stores   Pretty happy
#
#                 hapcohab compuse  wwwhr    ballot  log_wwwhr
# 53232  .i:  Inapplicable     YES    168  Ballot b   5.123964
# 55820  .i:  Inapplicable     YES    168  Ballot b   5.123964
# 60620  .i:  Inapplicable     YES    168  Ballot b   5.123964
# 67489  .i:  Inapplicable     YES    168  Ballot b   5.123964
# 71155  .i:  Inapplicable     YES    168  Ballot a   5.123964
# 71192  .i:  Inapplicable     YES    168  Ballot a   5.123964
# 71963       Pretty happy      NO    168  Ballot b   5.123964

# %%
fig, ax = plt.subplots(1,2,figsize=(12,5))
sns.histplot(data=df, x="log_wwwhr",ax=ax[0])
order = ["Pretty happy", "Very happy", "Not too happy"]
lines = ["--",":","-"] # dashed = happy, dotted = yay, 
sns.countplot(data=df, x="hapcohab", ax=ax[1], order=order)

for level,line in zip(order,lines):
    level_mean = df[df["hapcohab"] == level]["log_wwwhr"].mean()
    level_median = df[df["hapcohab"] == level]["log_wwwhr"].median()
    level_max = df[df["hapcohab"] == level]["log_wwwhr"].max()
    ax[0].axvline(level_mean, linestyle=line, color="b", label=f"{level} mean")
    ax[0].axvline(level_median, linestyle=line, color="g", label=f"{level} median")
    ax[0].axvline(level_max, linestyle=line, color="r", label=f"{level} max")

ax[0].legend(loc="upper right")

# %%
df['quantile_labels'] = pd.qcut(df['wwwhr'], 
                               q=4,
                               labels=['Q1', 'Q2', 'Q3', 'Q4'])

# %%
happy_mapping = {"Pretty happy":2, "Very happy":1, "Not too happy": 0}
hapcohab_mapping = {"Pretty happy":2, "Very happy":1, "Not too happy": 0}


df['happy_encoded'] = df['happy'].map(happy_mapping)
# df['hapcohab_encoded'] = df['hapcohab'].map(hapcohab_mapping)

sns.heatmap(df[["log_wwwhr","happy_encoded"]].corr(),annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ## Factoring Industry In Now
#
# So the previous analysis basically just said 1 thing, your happiness is related to the happiness of a relationship.
#
# I also realize now that I dropped the single people without a relationship, so that might effect it as well.

# %%
df.sort_values(by="wwwhr", ascending=False)[["indus10","wwwhr"]][:100].value_counts()
# Out:
# indus10                                                 wwwhr
# Computer systems design and related services            40       3
# Colleges and universities, including junior colleges    80       2
# Landscaping services                                    40       2
# Motion pictures and video industries                    50       2
# Real estate                                             50       2
#                                                                 ..
# Traveler accommodation                                  60       1
# Warehousing and storage                                 50       1
#                                                         65       1
# Water, steam, air-conditioning, and irrigation systems  50       1
# Wired telecommunications carriers                       50       1
# Name: count, Length: 92, dtype: int64

# %%
df.sort_values(by="wwwhr", ascending=False)[["occ10","wwwhr"]][:100].value_counts()
# Out:
# occ10                                                         wwwhr
# Accountants and auditors                                      40       2
# Postsecondary teachers                                        80       2
# Sales representatives, services, all other                    40       2
# Software developers, applications and systems software        50       2
# Market research analysts and marketing specialists            40       2
#                                                                       ..
# Sales representatives,  wholesale and manufacturing           40       1
# Securities, commodities, and financial services sales agents  70       1
# Statisticians                                                 40       1
# Tellers                                                       60       1
# Training and development managers                             60       1
# Name: count, Length: 94, dtype: int64
